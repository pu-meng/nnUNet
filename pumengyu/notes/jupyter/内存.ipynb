# %%
a=[1,2,3]
b=a
print(id(a))
print(id(b))
b.extend([4,5,6])
print(a)
print(b)

# %%
a=[1,2,3]
b=a.copy()
print(id(a))
print(id(b))
b.extend([4,5,6])
print(a)
print(b)

# %% [markdown]
#   import time, numpy as np
#   path = '/home/PuMengYu/nnUNet_workspace/preprocessed/Dataset003_Liver/nnUNet
#   Plans_3d_fullres/s2feat/liver_0.npy'
#   t = time.time()
#   x = np.load(path)
#   print(f'load: {time.time()-t:.2f}s, shape={x.shape}')

# %%
import time, numpy as np
path = '/home/PuMengYu/nnUNet_workspace/preprocessed/Dataset003_Liver/nnUNetPlans_3d_fullres/s2feat/liver_0.npy'
t = time.time()
x = np.load(path)
print(f'load: {time.time()-t:.2f}s, shape={x.shape}')
