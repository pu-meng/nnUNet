# %% [markdown]
#   $$\text{atanh}(x) = \frac{1}{2} \ln\frac{1+x}{1-x}$$
#
#   $$\text{Var}(z) \approx \frac{1}{n-3}$$
#
#
#   $$\tanh(x) = \frac{e^x - e^{-x}}{e^x + e^{-x}}$$
#
#
#   $$d = \frac{\mu_t - \mu_l}{\sigma_{pooled}}$$

# %% [markdown]
#   $$\sigma_{pooled} = \sqrt{\frac{(n_t-1)\sigma_t^2 + (n_l-1)\sigma_l^2}{n_t + n_l - 2}}$$

# %%
from scipy.stats import rankdata
a=[0.1,0.5,0.3,0.5]
print(rankdata(a,method="average"))
# Out:
# [1.  3.5 2.  3.5]

# %% [markdown]
#   多维 Mahalanobis 距离定义为：
#
#   $$D_M = \sqrt{(\mu_t - \mu_l)^T \Sigma^{-1} (\mu_t - \mu_l)}$$
#
#   降到一维后，协方差矩阵退化为一个标量——合并方差 $\sigma_p^2$，于是：
#
#   $$D_M = \frac{|\mu_t - \mu_l|}{\sigma_p}$$

# %% [markdown]
#   $$D_{KL}(p | q) = \sum_i p_i \ln\frac{p_i}{q_i}$$
#
#
#   引入混合分布 $M = \frac{p+q}{2}$，然后：
#
#   $$JSD(p | q) = \frac{1}{2} D_{KL}(p | M) + \frac{1}{2} D_{KL}(q | M)$$
#
#   $$D_{KS} = \max_x |CDF_t(x) - CDF_l(x)|$$

# %% [markdown]
# $$W_1(p, q) = \int_{-\infty}^{+\infty} |CDF_p(x) - CDF_q(x)| , dx$$

# %% [markdown]
#   $$U = \sum_{i,j} \mathbf{1}[t_i > l_j]$$
